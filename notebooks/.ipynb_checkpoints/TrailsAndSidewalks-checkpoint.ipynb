# %% [markdown]
# # Trails and Sidewalks
#
# From: https://www.denvergov.org/opendata/dataset/city-and-county-of-denver-trails-and-sidewalks

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
data = gpd.read_file("./data/trails_and_sidewalks.gdb", driver="OpenFileGDB")

# %%
data
# Out:
#                   LOCATION LOC_CODE             TRAIL_NAME REACH  PATH_TYPE  \
# 0              Town Center      558                   None  None          1
# 1             Wallace Park      612  Goldsmith Gulch Trail  None          2
# 2             Skyland Park      429                   None  None          1
# 3            Greenway Park      556                   None  None          1
# 4     City of Kunming Park      833                   None  None          1
# ...                    ...      ...                    ...   ...        ...
# 7169       Bear Creek Park      139       Bear Creek Trail  None          1
# 7170       Washington Park      711                   None  None          1
# 7171             Boyd Park      255                   None  None          1
# 7172    Thomas (Fred) Park      L16                   None  None          1
# 7173             Cook Park      763                   None  None          1
#
# ...

# %%
data.plot()
# Out:
# <AxesSubplot:>
