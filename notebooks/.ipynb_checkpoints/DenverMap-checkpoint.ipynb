# %%
import networkx as nx
import osmnx as ox
from pprint import pprint

# %%
G = ox.graph_from_place("Denver, Colorado, USA", network_type="drive")
fig, ax = ox.plot_graph(G, node_size=1)

# %%
G = ox.speed.add_edge_speeds(G)

# %%
for node in G.nodes:
    print(G.nodes[node])
    
    break
# Out:
# {'y': 39.7034891, 'x': -104.991885, 'street_count': 3}

# %%
for (u, v, _) in G.edges:
    pprint((u, v, G.get_edge_data(u, v)))
    
    break
# Out:
# (27512439,
#  468562728,
#  {0: {'access': 'designated',
#       'bridge': 'viaduct',
#       'geometry': <shapely.geometry.linestring.LineString object at 0x137488160>,
#       'highway': 'motorway',
#       'lanes': '5',
#       'length': 89.201,
#       'maxspeed': '55 mph',
#       'name': 'South Valley Highway',
#       'oneway': True,
#       'osmid': 37586942,
#       'ref': 'I 25',
#       'speed_kph': 88.5}})
