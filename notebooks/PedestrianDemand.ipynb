# %% [markdown]
# # Pedestrian Demand Index
#
# From Denver's OpenData: https://www.denvergov.org/opendata/dataset/city-and-county-of-denver-pedestrian-demand-index

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
data = gpd.read_file("./data/pedestrian_demand_index.gdb", driver="OpenFileGDB")

# %%
data
# Out:
#            GEOID10  PDI_Score PDI_Ranking  SHAPE_Length  SHAPE_Area  \
# 0    0803100412146         10        HIGH      0.005259    0.000002
# 1    0803100409310          8        HIGH      0.033493    0.000064
# 2    0803100410310          1         LOW      0.031635    0.000046
# 3    0803100407030          8        HIGH      0.040299    0.000073
# 4    0803100410130          8        HIGH      0.039525    0.000073
# ..             ...        ...         ...           ...         ...
# 474  0803100409140          5      MEDIUM      0.027482    0.000042
# 475  0803100407280          9        HIGH      0.044002    0.000084
# 476  0803100408310          7        HIGH      0.046236    0.000075
# 477  0803100405060          7        HIGH      0.046366    0.000057
# 478  0803100406020          8        HIGH      0.022927    0.000026
#
#                                               geometry
# 0    MULTIPOLYGON (((-104.99272 39.74744, -104.9929...
# ...

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 10), facecolor="white")
data.plot(column="PDI_Score", ax=ax, legend=True)
# Out:
# <AxesSubplot:>
